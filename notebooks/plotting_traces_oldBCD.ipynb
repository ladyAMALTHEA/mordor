# %%
#%autoreload
from trace_utils import *
from plot_utils import *
from bad_eggs import *

# %%
#LOAD TRACES
work_dir = '/Users/robinhood/O2_outputs/imgproc/traces/wt_pho_esc'
traces_list = []
file_list = [file for file in os.listdir(work_dir) if file[-4:] == '.npy']
for file in file_list:
    filename = os.path.join(work_dir, file)
    traces = load_traces(filename)
    traces_list.append(traces)

# %%
#FORMAT DATASTRUCTURE
all_traces = format_trace_datastructure(traces_list, bad_eggs)

# %%
bad_eggs
# Out:
# ['pho_20210929_BCDKr_13',
#  'pho_20210929_BCDKr_15',
#  'pho_20210929_BCDKr_17',
#  'pho_20210929_BCDKr_19',
#  'pho_20210929_BCDKr_22',
#  'pho_20210929_BCDKr_23',
#  'pho_20210929_BCDKr_4',
#  'pho_20210929_BCDKr_6',
#  'pho_20210929_BCDKr_7',
#  'wt_20210920_BCDKr_14',
#  'wt_20210920_BCDKr_22',
#  'wt_20210920_BCDKr_23',
#  'wt_20210920_BCDKr_3',
#  'wt_20210920_BCDKr_5',
#  'wt_20210920_BCDKr_7',
#  'wt_20210920_BCDKr_8',
#  'esc_20220423_BCDhb_5',
#  'esc_20220423_BCDhb_6',
#  'esc_20220423_BCDhb_12',
#  'esc_20220423_BCDhb_13',
#  'esc_20220423_BCDhb_16',
#  'esc_20220423_BCDhb_19',
#  'esc_20220423_BCDhb_20',
#  'wt_20220425_BCDhb_01',
#  'wt_20220425_BCDhb_09',
#  'wt_20220425_BCDhb_15',
#  'wt_20220425_BCDhb_17',
#  'wt_20220425_BCDhb_19',
#  'wt_20220425_BCDhb_22',
#  'wt_20220425_BCDhb_25',
#  'wt_20220425_BCDhb_27',
#  'wt_20220425_BCDhb_28',
#  'wt_20220425_BCDhb_35',
#  'pho_20220425_BCDhb_03',
#  'pho_20220425_BCDhb_04',
#  'pho_20220425_BCDhb_06',
#  'pho_20220425_BCDhb_07',
#  'pho_20220425_BCDhb_09',
#  'pho_20220425_BCDhb_12',
#  'pho_20220425_BCDhb_17',
#  'pho_20220425_BCDhb_18',
#  'pho_20220425_BCDhb_19',
#  'pho_20220425_BCDhb_26',
#  'pho_20220425_BCDhb_27',
#  'pho_20220425_BCDhb_30',
#  'pho_20220425_BCDhb_31',
#  'pho_20220425_BCDhb_32',
#  'pho_20220425_BCDhb_33',
#  'pho_20220425_BCDhb_34',
#  'esc_20220405_1',
#  'esc_20220405_3',
#  'esc_20220412_4',
#  'esc_20220405_10',
#  'esc_20220405_12',
#  'esc_20220405_21',
#  'esc_20220405_27',
#  'esc_20220405_28',
#  'esc_20220412_1',
#  'esc_20220412_3',
#  'esc_20220412_11',
#  'wt_20220328_gtCAD_1',
#  'wt_20220328_gtCAD_8',
#  'wt_20220328_gtCAD_9',
#  'wt_20220328_gtCAD_11',
#  'wt_20220328_gtCAD_12',
#  'wt_20220328_gtCAD_21',
#  'wt_20220328_gtCAD_22',
#  'wt_20220328_gtCAD_23',
#  'wt_20220328_gtCAD_25',
#  'wt_20220328_gtCAD_27',
#  'wt_20220328_gtCAD_29',
#  'wt_20220328_gtCAD_31',
#  'pho_20220330_gtCAD_2',
#  'pho_20220330_gtCAD_4',
#  'pho_20220330_gtCAD_5',
#  'pho_20220330_gtCAD_6',
#  'pho_20220330_gtCAD_7',
#  'pho_20220330_gtCAD_13',
#  'pho_20220330_gtCAD_15',
#  'pho_20220330_gtCAD_17',
#  'pho_20220330_gtCAD_22',
#  'wt_20220414_gtCAD_1',
#  'wt_20220414_gtCAD_9',
#  'wt_20220414_gtCAD_14',
#  'wt_20220414_gtCAD_24',
#  'wt_20220414_gtCAD_27',
#  'pho_20210427_gthb_12',
#  'pho_20210427_gthb_13',
#  'pho_20210427_gthb_2',
#  'pho_20210427_gthb_20',
#  'pho_20210427_gthb_4',
#  'pho_20210427_gthb_6',
#  'pho_20210427_gthb_7',
#  'pho_20210427_gthb_9',
#  'pho_20210429_gthb_1',
#  'pho_20210429_gthb_11',
#  'pho_20210429_gthb_20',
#  'pho_20210429_gthb_23',
#  'pho_20210429_gthb_30',
#  'wt_20210413_gthb_1',
#  'wt_20210413_gthb_10',
#  'wt_20210413_gthb_12',
#  'wt_20210413_gthb_13',
#  'wt_20210413_gthb_14',
#  'wt_20210413_gthb_16',
#  'wt_20210413_gthb_17',
#  'wt_20210413_gthb_18',
#  'wt_20210413_gthb_19',
#  'wt_20210413_gthb_2',
#  'wt_20210413_gthb_21',
#  'wt_20210413_gthb_22',
#  'wt_20210413_gthb_23',
#  'wt_20210413_gthb_24',
#  'wt_20210413_gthb_26',
#  'wt_20210413_gthb_27',
#  'wt_20210413_gthb_3',
#  'wt_20210413_gthb_30',
#  'wt_20210413_gthb_7',
#  'wt_20210413_gthb_8',
#  'wt_20210413_gthb_9',
#  'wt_20210510_gthb_8']

# %%
#PLOT
fig = show_all_traces(all_traces)
#plt.savefig("/Users/robinhood/O2_outputs/imgproc/traces/wt_pho/traces_all.svg", format="svg" )

# %%
#can list which genes/genotypes you want plotted, or omit/set to None to do all, and optionally display individual traces
fig = show_all_traces(all_traces, genotypes=['wt', 'pho', 'esc'], genes=None, individuals=True)

# %%
fig = show_all_traces(all_traces, genotypes=['wt', 'esc'], genes=['kr'])

# %%
#Plotting all of the genes for a single genotype:
fig = show_genotype_traces(all_traces, 'pho', genes = ['hb', 'BCD'], individuals=True)

# %%
#one stripe of giant only
from xtreme import *

#LOAD TRACES
work_dir = '/Users/robinhood/O2_outputs/imgproc/traces/xtreme_gt'
traces_list = []
file_list = [file for file in os.listdir(work_dir) if file[-4:] == '.npy']
for file in file_list:
    filename = os.path.join(work_dir, file)
    traces = load_traces(filename)
    traces_list.append(traces)

all_traces = format_trace_datastructure(traces_list, xtreme)

fig = show_all_traces(all_traces)

# %%
from excluded_14 import *
stage_excluded
excluded = excluded_14+stage_excluded
excluded

# %%
from trace_utils import *
from excluded_14 import *

#LOAD TRACES
work_dir = '/Users/robinhood/O2_outputs/imgproc/traces'
traces_list = []
file_list = [file for file in os.listdir(work_dir) if file[-4:] == '.npy']
for file in file_list:
    filename = os.path.join(work_dir, file)
    traces = load_traces(filename)
    traces_list.append(traces)

all_traces = format_trace_datastructure(traces_list, excluded_14)
fig = show_all_traces(all_traces, genotypes=['wt'], genes='hb', 'BCD', 'kr', 'gt')
# plt.savefig("/Users/robinhood/O2_outputs/imgproc/traces/traces_pcs.svg", format="svg" )
# plt.savefig("/Users/robinhood/O2_outputs/imgproc/traces/wt_pho/traces_nc14.svg", format="svg" )
# Out:
#   File "/var/folders/8g/xxkf18yx5b9fx5rg19w8b75h0000gn/T/ipykernel_82132/3142988889.py", line 14
#     fig = show_all_traces(all_traces, genotypes=['wt'], genes='hb', 'BCD', 'kr', 'gt')
#                                                                                      ^
# SyntaxError: positional argument follows keyword argument

# %%
genotypes = list(all_traces.keys())
color_dict = get_color_dict(genotypes)
fig = show_all_traces(all_traces, color_dict=color_dict, genotypes=['wt', 'sfmbt'])
plt.savefig("/Users/robinhood/O2_outputs/imgproc/traces/traces_sfmbt.svg", format="svg" )

# %%
genotype = 'wt'
# genes = list(all_traces[genotype].keys())
genes = ['hb', 'BCD', 'kr', 'gt']
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
for gene in genes:
    if gene not in all_traces[genotype].keys():
        continue
    traces = all_traces[genotype][gene]
    mean_traces = np.nanmean(traces, 1)
    n = mean_traces.shape[0]
    mean = np.nanmean(mean_traces, 0)
    error = np.nanstd(mean_traces, 0) / mean_traces.shape[0]
    ax.fill_between(np.arange(mean.shape[0]), mean-error, mean+error, alpha=0.5, linewidth=0)#, color=color_dict[genotype])
    ax.plot(mean, label=f'{gene} (n = {n})')#, color=color_dict[genotype])
    ax.set_title(f'{genotype} Mean Traces (w/ Std)')
    ax.legend()

    plt.savefig("/Users/robinhood/O2_outputs/imgproc/traces/traces_wtall.svg", format="svg" )

# %%
genotype = 'pho'
# genes = list(all_traces[genotype].keys())
genes = ['hb', 'BCD', 'kr', 'gt']
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
for gene in genes:
    if gene not in all_traces[genotype].keys():
        continue
    traces = all_traces[genotype][gene]
    mean_traces = np.nanmean(traces, 1)
    n = mean_traces.shape[0]
    mean = np.nanmean(mean_traces, 0)
    error = np.nanstd(mean_traces, 0) / mean_traces.shape[0]
    ax.fill_between(np.arange(mean.shape[0]), mean-error, mean+error, alpha=0.5, linewidth=0)#, color=color_dict[genotype])
    ax.plot(mean, label=f'{gene} (n = {n})')#, color=color_dict[genotype])
    ax.set_title(f'{genotype} Mean Traces (w/ Std)')
    ax.legend()

    plt.savefig("/Users/robinhood/O2_outputs/imgproc/traces/traces_phoall.svg", format="svg" )
